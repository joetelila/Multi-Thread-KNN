# %%
# importing libraries
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
import numpy as np
font = {'size':13}
plt.rc('font', **font)

# %%
df = pd.read_csv('pinThread_branch_data.csv')

# %%
df.head()
# Out:
#    Threads    Test Data    STL PAR  stl_sc(nw)  stl_sp(nw)  stl_eff(nw)  \
# 0        1  xx_20k_s123  14.177500    1.000000    0.994456     0.994456
# 1        2  xx_20k_s123   7.317820    1.937394    1.926653     0.963327
# 2        4  xx_20k_s123   3.867540    3.665767    3.645444     0.911361
# 3        8  xx_20k_s123   1.940070    7.307726    7.267212     0.908402
# 4       16  xx_20k_s123   0.987178   14.361645   14.282024     0.892627
#
#    OMP PAR  omp_sc(nw)  omp_sp(nw)  omp_eff(nw)   FF PAR  ff_sc(nw)  \
# 0  14.1249      1.0000      0.9982       0.9982  14.1023     1.0000
# 1   7.4854      1.8870      1.8835       0.9418   7.2599     1.9425
# 2   3.7520      3.7646      3.7577       0.9394   3.8649     3.6488
# 3   1.9008      7.4311      7.4174       0.9272   1.9376     7.2782
# 4   0.9471     14.9131     14.8857       0.9304   0.9878    14.2765
#
#    ff_sp(nw)  ff_eff(nw)
# 0     0.9998      0.9998
# 1     1.9420      0.9710
# 2     3.6480      0.9120
# 3     7.2764      0.9096
# 4    14.2731      0.8921

# %%
#Plotting speed up: for all programs over the data.
data = ['xx_20k_s123', 'xx_50k_s456','xx_100k_s789']
implementations = ['STL','OMP','FF']
speedups = ['stl_sp(nw)','omp_sp(nw)','ff_sp(nw)']
scalability = ['stl_sc(nw)','omp_sc(nw)','ff_sc(nw)']
efficiency = ['stl_eff(nw)','omp_eff(nw)','ff_eff(nw)']
nw = ['1', '2', '4', '8', '16', '32', '64', '128', '256']

# %% [markdown]
# ## Statistics for 20k

# %%
df_20k = df[df['Test Data']==data[0]]

# %%
# Plotting speedups
sp_list = []
for sp in speedups:
    sp_list.append(list(df_20k[sp]))
sc_list = []
for sc in scalability:
    sc_list.append(list(df_20k[sc]))
eff_lsit = []
for eff in efficiency:
    eff_lsit.append(list(df_20k[eff]))

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 17))
for i in range(len(speedups)):
    axs[0].plot(nw, sp_list[i], label = implementations[i])
    axs[1].plot(nw, sc_list[i], label = implementations[i])
    axs[2].plot(nw, eff_lsit[i], label = implementations[i])
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[0].set_ylabel("Speedup")
axs[0].set_xlabel("Number of workers")
axs[1].set_ylabel("Scalability")
axs[1].set_xlabel("Number of workers")
axs[2].set_ylabel("Efficiency")
axs[2].set_xlabel("Number of workers")
# Out:
# Text(0.5, 0, 'Number of workers')

# %% [markdown]
# ## Statistics for 50k

# %%
df_50k = df[df['Test Data']==data[1]]

# %%
# Plotting speedups
sp_list = []
for sp in speedups:
    sp_list.append(list(df_50k[sp]))
sc_list = []
for sc in scalability:
    sc_list.append(list(df_50k[sc]))
eff_lsit = []
for eff in efficiency:
    eff_lsit.append(list(df_50k[eff]))

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 17))
for i in range(len(speedups)):
    axs[0].plot(nw, sp_list[i], label = implementations[i])
    axs[1].plot(nw, sc_list[i], label = implementations[i])
    axs[2].plot(nw, eff_lsit[i], label = implementations[i])
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[0].set_ylabel("Speedup")
axs[0].set_xlabel("Number of workers")
axs[1].set_ylabel("Scalability")
axs[1].set_xlabel("Number of workers")
axs[2].set_ylabel("Efficiency")
axs[2].set_xlabel("Number of workers")
# Out:
# Text(0.5, 0, 'Number of workers')

# %% [markdown]
# ## Statistics for 100k

# %%
df_100k = df[df['Test Data']==data[2]]

# %%
# Plotting speedups
sp_list = []
for sp in speedups:
    sp_list.append(list(df_100k[sp]))
sc_list = []
for sc in scalability:
    sc_list.append(list(df_100k[sc]))
eff_lsit = []
for eff in efficiency:
    eff_lsit.append(list(df_100k[eff]))

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 17))
for i in range(len(speedups)):
    axs[0].plot(nw, sp_list[i], label = implementations[i])
    axs[1].plot(nw, sc_list[i], label = implementations[i])
    axs[2].plot(nw, eff_lsit[i], label = implementations[i])
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[0].set_ylabel("Speedup")
axs[0].set_xlabel("Number of workers")
axs[1].set_ylabel("Scalability")
axs[1].set_xlabel("Number of workers")
axs[2].set_ylabel("Efficiency")
axs[2].set_xlabel("Number of workers")
# Out:
# Text(0.5, 0, 'Number of workers')
